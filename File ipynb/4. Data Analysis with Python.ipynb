# %%
import pandas as pd

# %%
# Danh sách file processed và tên mã
files = [
    ("META", "data/META/META_processed.csv"),
    ("RDDT", "data/RDDT/RDDT_processed.csv")
]

# %%
for ticker, file_path in files:
    print(f"\n===== PHÂN TÍCH CHO {ticker} =====")
    df = pd.read_csv(file_path, index_col=0)

    # In 5 dòng đầu của data
    print("\n5 dòng đầu của dataset:")
    print(df.head())

    # Thông tin cơ bản về dataset
    print("\nThông tin cơ bản về dataset:")
    print(df.info())

    # Thống kê mô tả cơ bản
    print("\nThống kê mô tả cơ bản:")
    print(df.describe())

    # Kiểm tra missing values
    print("\nSố lượng missing values trong mỗi cột:")
    print(df.isnull().sum())

    # Nhóm dữ liệu theo cột 'target' và tính trung bình
    if 'target' in df.columns:
        grouped_by_target = df.groupby('target').mean(numeric_only=True)
        print("\nTrung bình các chỉ số theo mức độ biến động (target):")
        print(grouped_by_target)
    else:
        print("\nKhông tìm thấy cột 'target' để nhóm dữ liệu.")

    # Hàm tìm outliers sử dụng phương pháp IQR
    def find_outliers(column):
        Q1 = column.quantile(0.25)
        Q3 = column.quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        return column[(column < lower_bound) | (column > upper_bound)]

    # Tìm outliers trong các cột quan trọng
    for col in ['biendong', 'tangtoida', 'giamtoida']:
        if col in df.columns:
            outliers = find_outliers(df[col])
            print(f"\nCác giá trị ngoại lệ trong cột '{col}':")
            print(outliers)
        else:
            print(f"\nKhông tìm thấy cột '{col}' trong dữ liệu.")

    # Tính ma trận tương quan
    correlation_matrix = df.corr(numeric_only=True)
    print("\nMa trận tương quan giữa các chỉ số:")
    print(correlation_matrix)

    # Lọc ra các tương quan mạnh với cột 'target'
    if 'target' in correlation_matrix.columns:
        target_correlations = correlation_matrix['target'].sort_values(ascending=False)
        print("\nTương quan giữa các chỉ số với cột 'target':")
        print(target_correlations)
    else:
        print("\nKhông tìm thấy cột 'target' trong ma trận tương quan.")

    # Phân bố biến động tối đa theo nhóm
    group_cols = ['biendong', 'tangtoida', 'giamtoida']
    for col in group_cols:
        if 'target' in df.columns and col in df.columns:
            distribution = df.groupby('target')[col].describe()
            print(f"\nPhân bố {col} theo nhóm:")
            print(distribution)
        else:
            print(f"\nKhông đủ cột để phân tích phân bố {col} theo nhóm.")
# Out:
# ===== PHÂN TÍCH CHO META =====
#
# 5 dòng đầu của dataset:
#                Close      High       Low      Open    Volume  rolling_mean_5  \
# Date
# 2024-01-08  0.003197  0.000000  0.000000  0.000000  0.413938        0.000000
# 2024-01-09  0.000000  0.004224  0.008570  0.004315  0.394683        0.005884
# 2024-01-10  0.033896  0.035519  0.018202  0.013886  0.785548        0.019618
# 2024-01-11  0.031816  0.035112  0.028170  0.044246  0.563685        0.031529
# 2024-01-12  0.044345  0.046002  0.045284  0.039245  0.658748        0.043435
#
#             rolling_std_5  volatility  price_change_pct  biendong  tangtoida  \
# Date
# 2024-01-08       0.102712    0.085057          0.500951  0.103902   0.132936
# 2024-01-09       0.115976    0.029921          0.424305  0.019047   0.131694
# 2024-01-10       0.185265    0.316628          0.560297  0.201920   0.396632
# 2024-01-11       0.167400    0.182630          0.428633  0.012388   0.020189
# 2024-01-12       0.154388    0.104771          0.480417  0.074636   0.214312
#
#             giamtoida  target
# Date
# 2024-01-08   0.078244       0
# 2024-01-09   0.030707       0
# 2024-01-10   0.032184       1
# 2024-01-11   0.271636       0
# 2024-01-12   0.018306       0
#
# Thông tin cơ bản về dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 2024-01-08 to 2025-06-30
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Close             350 non-null    float64
#  1   High              350 non-null    float64
#  2   Low               350 non-null    float64
#  3   Open              350 non-null    float64
#  4   Volume            350 non-null    float64
#  5   rolling_mean_5    350 non-null    float64
#  6   rolling_std_5     350 non-null    float64
#  7   volatility        350 non-null    float64
#  8   price_change_pct  350 non-null    float64
#  9   biendong          350 non-null    float64
#  10  tangtoida         350 non-null    float64
#  11  giamtoida         350 non-null    float64
#  12  target            350 non-null    int64
# dtypes: float64(12), int64(1)
# memory usage: 38.3+ KB
# None
#
# Thống kê mô tả cơ bản:
#             Close        High         Low        Open      Volume  \
# count  350.000000  350.000000  350.000000  350.000000  350.000000
# mean     0.512561    0.514940    0.505568    0.507125    0.410634
# std      0.216809    0.214861    0.213285    0.212471    0.199001
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.359254    0.366265    0.353558    0.357731    0.266105
# 50%      0.483861    0.489121    0.470674    0.485662    0.373525
# 75%      0.658098    0.659739    0.644892    0.653800    0.530684
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        rolling_mean_5  rolling_std_5  volatility  price_change_pct  \
# count      350.000000     350.000000  350.000000        350.000000
# mean         0.535364       0.224779    0.322929          0.444106
# std          0.219245       0.173488    0.206778          0.076291
# min          0.000000       0.000000    0.000000          0.000000
# 25%          0.385689       0.104695    0.174414          0.409247
# 50%          0.501101       0.179773    0.279064          0.442594
# 75%          0.687259       0.295121    0.418772          0.479734
# max          1.000000       1.000000    1.000000          1.000000
#
#          biendong   tangtoida   giamtoida      target
# count  350.000000  350.000000  350.000000  350.000000
# mean     0.130613    0.213976    0.211385    0.080000
# std      0.131199    0.176981    0.187708    0.518318
# min      0.000000    0.000000    0.000000   -1.000000
# 25%      0.038409    0.080440    0.071397    0.000000
# 50%      0.094014    0.170939    0.157912    0.000000
# 75%      0.187587    0.300025    0.292386    0.000000
# max      1.000000    1.000000    1.000000    1.000000
#
# Số lượng missing values trong mỗi cột:
# Close               0
# High                0
# Low                 0
# Open                0
# Volume              0
# rolling_mean_5      0
# rolling_std_5       0
# volatility          0
# price_change_pct    0
# biendong            0
# tangtoida           0
# giamtoida           0
# target              0
# dtype: int64
#
# Trung bình các chỉ số theo mức độ biến động (target):
#            Close      High       Low      Open    Volume  rolling_mean_5  \
# target
# -1      0.493783  0.520909  0.490915  0.520110  0.591350        0.566151
#  0      0.514599  0.515573  0.510571  0.510413  0.361486        0.538981
#  1      0.514509  0.509073  0.493110  0.486533  0.512880        0.503662
#
#         rolling_std_5  volatility  price_change_pct  biendong  tangtoida  \
# target
# -1           0.325184    0.590439          0.312112  0.316398   0.127964
#  0           0.193642    0.266682          0.436166  0.071252   0.181471
#  1           0.297279    0.406660          0.549018  0.271918   0.394313
#
#         giamtoida
# target
# -1       0.529517
#  0       0.192587
#  1       0.113939
#
# Các giá trị ngoại lệ trong cột 'biendong':
# Date
# 2024-02-06    1.000000
# 2024-04-29    0.984010
# 2024-07-05    0.464718
# 2024-07-24    0.425463
# 2025-01-28    0.417196
# 2025-03-06    0.443621
# 2025-03-10    0.430097
# 2025-03-13    0.449527
# 2025-04-11    0.627906
# 2025-05-02    0.662445
# 2025-05-12    0.730275
# Name: biendong, dtype: float64
#
# Các giá trị ngoại lệ trong cột 'tangtoida':
# Date
# 2024-05-01    0.664139
# 2024-07-05    0.910986
# 2024-08-05    1.000000
# 2024-08-06    0.733271
# 2025-02-03    0.875801
# 2025-02-26    0.728326
# 2025-03-20    0.856296
# 2025-05-02    0.651584
# 2025-06-02    0.900920
# Name: tangtoida, dtype: float64
#
# Các giá trị ngoại lệ trong cột 'giamtoida':
# Date
# 2024-04-19    0.800106
# 2024-07-11    0.666284
# 2024-09-06    0.699125
# 2024-10-31    0.651223
# 2024-12-18    0.731476
# 2025-01-07    0.695615
# 2025-02-18    0.876112
# 2025-02-24    0.706284
# 2025-02-25    0.714582
# 2025-02-27    0.737404
# 2025-03-03    0.676941
# 2025-03-04    0.647895
# 2025-03-06    0.708062
# 2025-03-07    0.733848
# 2025-03-10    0.628335
# 2025-03-13    1.000000
# 2025-03-18    0.753189
# 2025-03-28    0.782854
# 2025-04-14    0.827350
# 2025-06-20    0.655503
# Name: giamtoida, dtype: float64
#
# Ma trận tương quan giữa các chỉ số:
#                      Close      High       Low      Open    Volume  \
# Close             1.000000  0.997601  0.997955  0.994507 -0.111462
# High              0.997601  1.000000  0.997555  0.997743 -0.090400
# Low               0.997955  0.997555  1.000000  0.997196 -0.129371
# Open              0.994507  0.997743  0.997196  1.000000 -0.109633
# Volume           -0.111462 -0.090400 -0.129371 -0.109633  1.000000
# rolling_mean_5    0.987370  0.989906  0.988351  0.990375 -0.120100
# rolling_std_5     0.141639  0.151783  0.131343  0.141694  0.398353
# volatility        0.328830  0.366896  0.300992  0.340874  0.488557
# price_change_pct  0.031526 -0.001537  0.003698 -0.033863  0.049217
# biendong          0.099659  0.113809  0.081845  0.098942  0.417451
# tangtoida         0.176022  0.164060  0.135859  0.097444  0.270673
# giamtoida         0.162302  0.210075  0.171203  0.244452  0.232937
# target            0.019359 -0.014581 -0.007107 -0.044705  0.005414
#
#                   rolling_mean_5  rolling_std_5  volatility  price_change_pct  \
# Close                   0.987370       0.141639    0.328830          0.031526
# High                    0.989906       0.151783    0.366896         -0.001537
# Low                     0.988351       0.131343    0.300992          0.003698
# Open                    0.990375       0.141694    0.340874         -0.033863
# Volume                 -0.120100       0.398353    0.488557          0.049217
# rolling_mean_5          1.000000       0.125139    0.351686         -0.083697
# rolling_std_5           0.125139       1.000000    0.322845          0.043993
# volatility              0.351686       0.322845    1.000000         -0.070215
# price_change_pct       -0.083697       0.043993   -0.070215          1.000000
# biendong                0.092504       0.381611    0.463557          0.116771
# tangtoida               0.122692       0.168058    0.430271          0.474638
# giamtoida               0.232347       0.163613    0.587707         -0.493753
# target                 -0.075952       0.034453   -0.104373          0.796522
#
#                   biendong  tangtoida  giamtoida    target
# Close             0.099659   0.176022   0.162302  0.019359
# High              0.113809   0.164060   0.210075 -0.014581
# Low               0.081845   0.135859   0.171203 -0.007107
# Open              0.098942   0.097444   0.244452 -0.044705
# Volume            0.417451   0.270673   0.232937  0.005414
# rolling_mean_5    0.092504   0.122692   0.232347 -0.075952
# rolling_std_5     0.381611   0.168058   0.163613  0.034453
# volatility        0.463557   0.430271   0.587707 -0.104373
# price_change_pct  0.116771   0.474638  -0.493753  0.796522
# biendong          1.000000   0.233273   0.242126  0.102989
# tangtoida         0.233273   1.000000  -0.477478  0.440591
# giamtoida         0.242126  -0.477478   1.000000 -0.496485
# target            0.102989   0.440591  -0.496485  1.000000
#
# Tương quan giữa các chỉ số với cột 'target':
# target              1.000000
# price_change_pct    0.796522
# tangtoida           0.440591
# biendong            0.102989
# rolling_std_5       0.034453
# Close               0.019359
# Volume              0.005414
# Low                -0.007107
# High               -0.014581
# Open               -0.044705
# rolling_mean_5     -0.075952
# volatility         -0.104373
# giamtoida          -0.496485
# Name: target, dtype: float64
#
# Phân bố biendong theo nhóm:
#         count      mean       std       min       25%       50%       75%  \
# target
# -1       34.0  0.316398  0.156794  0.153608  0.222627  0.273107  0.356515
#  0      254.0  0.071252  0.051097  0.000000  0.029288  0.063266  0.107219
#  1       62.0  0.271918  0.141941  0.120160  0.200610  0.236122  0.300764
#
#              max
# target
# -1      0.984010
#  0      0.212836
#  1      1.000000
#
# Phân bố tangtoida theo nhóm:
#         count      mean       std       min       25%       50%       75%  \
# target
# -1       34.0  0.127964  0.178784  0.000000  0.033898  0.077841  0.150549
#  0      254.0  0.181471  0.144268  0.000000  0.074854  0.156448  0.259004
#  1       62.0  0.394313  0.184417  0.095491  0.245257  0.381099  0.479886
#
#              max
# target
# -1      1.000000
#  0      0.875801
#  1      0.910986
#
# Phân bố giamtoida theo nhóm:
#         count      mean       std       min       25%       50%       75%  \
# target
# -1       34.0  0.529517  0.245704  0.016273  0.343288  0.579292  0.707618
#  0      254.0  0.192587  0.146912  0.001483  0.078972  0.163756  0.280258
#  1       62.0  0.113939  0.108977  0.000000  0.050748  0.079099  0.145348
#
#              max
# target
# -1      1.000000
#  0      0.733848
#  1      0.609071
#
# ===== PHÂN TÍCH CHO RDDT =====
#
# 5 dòng đầu của dataset:
#                Close      High       Low      Open    Volume  rolling_mean_5  \
# Date
# 2024-04-04  0.035526  0.041227  0.042085  0.041579  0.269700        0.039545
# 2024-04-05  0.045093  0.040489  0.039805  0.036211  0.137008        0.037590
# 2024-04-08  0.037515  0.045178  0.041759  0.047684  0.115834        0.037790
# 2024-04-09  0.031334  0.036274  0.040999  0.040000  0.085625        0.031736
# 2024-04-10  0.015694  0.021037  0.023731  0.027368  0.248604        0.026293
#
#             rolling_std_5  volatility  price_change_pct  biendong  tangtoida  \
# Date
# 2024-04-04       0.087759    0.081845          0.220660  0.037809   0.068760
# 2024-04-05       0.077045    0.092810          0.344136  0.056072   0.103736
# 2024-04-08       0.075378    0.113565          0.213216  0.044217   0.052464
# 2024-04-09       0.030818    0.052867          0.222249  0.035886   0.043323
# 2024-04-10       0.084815    0.064145          0.146313  0.092278   0.023768
#
#             giamtoida  target
# Date
# 2024-04-04   0.093567      -1
# 2024-04-05   0.058480       1
# 2024-04-08   0.164912      -1
# 2024-04-09   0.087719      -1
# 2024-04-10   0.133333      -1
#
# Thông tin cơ bản về dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 294 entries, 2024-04-04 to 2025-06-30
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Close             294 non-null    float64
#  1   High              294 non-null    float64
#  2   Low               294 non-null    float64
#  3   Open              294 non-null    float64
#  4   Volume            294 non-null    float64
#  5   rolling_mean_5    294 non-null    float64
#  6   rolling_std_5     294 non-null    float64
#  7   volatility        294 non-null    float64
#  8   price_change_pct  294 non-null    float64
#  9   biendong          294 non-null    float64
#  10  tangtoida         294 non-null    float64
#  11  giamtoida         294 non-null    float64
#  12  target            294 non-null    int64
# dtypes: float64(12), int64(1)
# memory usage: 32.2+ KB
# None
#
# Thống kê mô tả cơ bản:
#             Close        High         Low        Open      Volume  \
# count  294.000000  294.000000  294.000000  294.000000  294.000000
# mean     0.338367    0.340585    0.333383    0.331930    0.318341
# std      0.259246    0.261600    0.253156    0.253767    0.221676
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.110193    0.108638    0.110195    0.111579    0.150762
# 50%      0.298801    0.296778    0.280217    0.288079    0.256290
# 75%      0.520988    0.531835    0.513997    0.516599    0.441865
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        rolling_mean_5  rolling_std_5  volatility  price_change_pct  \
# count      294.000000     294.000000  294.000000        294.000000
# mean         0.338133       0.209920    0.206264          0.279824
# std          0.266796       0.187580    0.161945          0.098064
# min          0.000000       0.000000    0.000000          0.000000
# 25%          0.102302       0.073030    0.080671          0.223470
# 50%          0.306116       0.138520    0.155467          0.271549
# 75%          0.527032       0.288853    0.294780          0.332137
# max          1.000000       1.000000    1.000000          1.000000
#
#          biendong   tangtoida   giamtoida      target
# count  294.000000  294.000000  294.000000  294.000000
# mean     0.118508    0.134459    0.182701    0.044218
# std      0.135297    0.135730    0.192620    0.793371
# min      0.000000    0.000000    0.000000   -1.000000
# 25%      0.029478    0.045310    0.049123   -1.000000
# 50%      0.073534    0.091018    0.115497    0.000000
# 75%      0.156280    0.181936    0.234503    1.000000
# max      1.000000    1.000000    1.000000    1.000000
#
# Số lượng missing values trong mỗi cột:
# Close               0
# High                0
# Low                 0
# Open                0
# Volume              0
# rolling_mean_5      0
# rolling_std_5       0
# volatility          0
# price_change_pct    0
# biendong            0
# tangtoida           0
# giamtoida           0
# target              0
# dtype: int64
#
# Trung bình các chỉ số theo mức độ biến động (target):
#            Close      High       Low      Open    Volume  rolling_mean_5  \
# target
# -1      0.315562  0.329157  0.317267  0.330026  0.350591        0.339162
#  0      0.350536  0.351270  0.349825  0.345759  0.244852        0.352632
#  1      0.344781  0.338747  0.329281  0.318358  0.371238        0.321276
#
#         rolling_std_5  volatility  price_change_pct  biendong  tangtoida  \
# target
# -1           0.250255    0.237541          0.180959  0.162314   0.062625
#  0           0.170110    0.167123          0.267351  0.029660   0.110635
#  1           0.218712    0.222190          0.379442  0.178278   0.223091
#
#         giamtoida
# target
# -1       0.335099
#  0       0.159304
#  1       0.076074
#
# Các giá trị ngoại lệ trong cột 'biendong':
# Date
# 2024-11-01    1.000000
# 2024-11-05    0.432874
# 2024-11-21    0.695931
# 2024-11-25    0.515540
# 2025-01-03    0.378084
# 2025-01-21    0.415252
# 2025-01-28    0.445050
# 2025-02-04    0.415572
# 2025-02-11    0.356937
# 2025-02-14    0.642742
# 2025-02-20    0.454662
# 2025-03-06    0.569369
# 2025-03-07    0.535405
# 2025-03-18    0.579302
# 2025-04-03    0.402755
# 2025-04-09    0.702980
# 2025-06-18    0.478372
# Name: biendong, dtype: float64
#
# Các giá trị ngoại lệ trong cột 'tangtoida':
# Date
# 2024-11-05    0.484102
# 2024-11-07    0.464229
# 2024-11-21    0.684420
# 2024-12-03    0.419714
# 2024-12-06    0.463434
# 2024-12-16    0.440779
# 2024-12-20    0.441971
# 2025-01-03    0.544118
# 2025-01-21    0.536566
# 2025-01-28    0.509936
# 2025-02-03    0.651033
# 2025-04-07    0.635532
# 2025-04-09    1.000000
# 2025-06-18    0.459857
# Name: tangtoida, dtype: float64
#
# Các giá trị ngoại lệ trong cột 'giamtoida':
# Date
# 2024-11-11    0.625731
# 2024-11-25    0.601170
# 2024-11-26    0.536549
# 2024-12-10    0.967837
# 2024-12-17    0.574853
# 2024-12-18    0.859649
# 2025-01-07    0.534620
# 2025-01-10    0.538012
# 2025-01-30    0.543860
# 2025-02-06    0.785965
# 2025-02-11    0.625731
# 2025-02-14    0.551462
# 2025-02-18    0.561403
# 2025-02-20    1.000000
# 2025-02-21    0.796316
# 2025-02-24    0.618129
# 2025-02-25    0.541520
# 2025-02-27    0.842691
# 2025-03-04    0.561111
# 2025-03-06    0.583041
# 2025-03-07    0.921638
# 2025-03-13    0.668421
# 2025-03-18    0.727544
# 2025-04-04    0.548538
# 2025-04-08    0.600000
# 2025-05-15    0.539767
# 2025-06-25    0.553802
# Name: giamtoida, dtype: float64
#
# Ma trận tương quan giữa các chỉ số:
#                      Close      High       Low      Open    Volume  \
# Close             1.000000  0.998455  0.998233  0.995458  0.394350
# High              0.998455  1.000000  0.998295  0.997996  0.406111
# Low               0.998233  0.998295  1.000000  0.998154  0.379690
# Open              0.995458  0.997996  0.998154  1.000000  0.391545
# Volume            0.394350  0.406111  0.379690  0.391545  1.000000
# rolling_mean_5    0.991571  0.993110  0.992272  0.993924  0.397279
# rolling_std_5     0.606958  0.614038  0.598194  0.610443  0.554386
# volatility        0.735082  0.752936  0.713234  0.730456  0.595809
# price_change_pct  0.035645  0.007386  0.002605 -0.030544  0.121706
# biendong          0.422493  0.429855  0.403032  0.410998  0.565971
# tangtoida         0.462508  0.449143  0.422111  0.391704  0.376564
# giamtoida         0.443390  0.479663  0.457842  0.510991  0.357636
# target            0.043081  0.013171  0.016651 -0.020002  0.047803
#
#                   rolling_mean_5  rolling_std_5  volatility  price_change_pct  \
# Close                   0.991571       0.606958    0.735082          0.035645
# High                    0.993110       0.614038    0.752936          0.007386
# Low                     0.992272       0.598194    0.713234          0.002605
# Open                    0.993924       0.610443    0.730456         -0.030544
# Volume                  0.397279       0.554386    0.595809          0.121706
# rolling_mean_5          1.000000       0.609655    0.738093         -0.052001
# rolling_std_5           0.609655       1.000000    0.629132          0.035923
# volatility              0.738093       0.629132    1.000000          0.059320
# price_change_pct       -0.052001       0.035923    0.059320          1.000000
# biendong                0.406579       0.576134    0.617763          0.253120
# tangtoida               0.406444       0.309161    0.634268          0.538646
# giamtoida               0.505297       0.469355    0.597922         -0.483983
# target                 -0.028336      -0.059590   -0.029569          0.805613
#
#                   biendong  tangtoida  giamtoida    target
# Close             0.422493   0.462508   0.443390  0.043081
# High              0.429855   0.449143   0.479663  0.013171
# Low               0.403032   0.422111   0.457842  0.016651
# Open              0.410998   0.391704   0.510991 -0.020002
# Volume            0.565971   0.376564   0.357636  0.047803
# rolling_mean_5    0.406579   0.406444   0.505297 -0.028336
# rolling_std_5     0.576134   0.309161   0.469355 -0.059590
# volatility        0.617763   0.634268   0.597922 -0.029569
# price_change_pct  0.253120   0.538646  -0.483983  0.805613
# biendong          1.000000   0.447147   0.312019  0.068357
# tangtoida         0.447147   1.000000  -0.240449  0.473903
# giamtoida         0.312019  -0.240449   1.000000 -0.528461
# target            0.068357   0.473903  -0.528461  1.000000
#
# Tương quan giữa các chỉ số với cột 'target':
# target              1.000000
# price_change_pct    0.805613
# tangtoida           0.473903
# biendong            0.068357
# Volume              0.047803
# Close               0.043081
# Low                 0.016651
# High                0.013171
# Open               -0.020002
# rolling_mean_5     -0.028336
# volatility         -0.029569
# rolling_std_5      -0.059590
# giamtoida          -0.528461
# Name: target, dtype: float64
#
# Phân bố biendong theo nhóm:
#         count      mean       std       min       25%       50%       75%  \
# target
# -1       86.0  0.162314  0.138054  0.025953  0.070490  0.104454  0.213954
#  0      109.0  0.029660  0.023970  0.000000  0.012816  0.023710  0.036527
#  1       99.0  0.178278  0.153272  0.035245  0.077219  0.137135  0.227171
#
#              max
# target
# -1      0.642742
#  0      0.101570
#  1      1.000000
#
# Phân bố tangtoida theo nhóm:
#         count      mean       std       min       25%       50%       75%  \
# target
# -1       86.0  0.062625  0.063997  0.000000  0.017190  0.045707  0.089080
#  0      109.0  0.110635  0.100942  0.000000  0.049086  0.076709  0.134738
#  1       99.0  0.223091  0.164934  0.003975  0.107611  0.182035  0.301868
#
#              max
# target
# -1      0.332393
#  0      0.651033
#  1      1.000000
#
# Phân bố giamtoida theo nhóm:
#         count      mean       std       min       25%       50%       75%  \
# target
# -1       86.0  0.335099  0.241394  0.005263  0.158772  0.249416  0.536067
#  0      109.0  0.159304  0.142149  0.000000  0.060819  0.104094  0.212281
#  1       99.0  0.076074  0.075122  0.000000  0.019298  0.049124  0.108187
#
#              max
# target
# -1      1.000000
#  0      0.618129
#  1      0.311637
